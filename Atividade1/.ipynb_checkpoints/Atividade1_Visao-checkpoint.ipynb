# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.4.1

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# 1. Não aproveita bem a faixa pq ta muito concentrada nos tons escuros (mais a esquerda), poderia estar mais distribuida.

# %% [markdown]
# 2.

# %%
rintin_gray
# Out:
# array([[21, 39, 42, ..., 41, 41, 37],
#        [22, 40, 44, ..., 42, 42, 37],
#        [23, 41, 45, ..., 42, 43, 38],
#        ...,
#        [14, 28, 35, ..., 18, 18, 17],
#        [16, 29, 36, ..., 18, 17, 17],
#        [18, 31, 38, ..., 18, 17, 17]], dtype=uint8)

# %%
maxi = []
mini = []
for linha in rintin_gray:
    mini.append(min(linha, key=int))
    maxi.append(max(linha, key=int))

print(min(mini, key=int))
print(max(maxi, key=int))
# Out:
# 8
# 58

# %%
a = 5.1
b = -40.8
nova_lista = []

for linha in rintin_gray:
    nova_linha = []
    for numero in linha:
        novo = numero * a + b
        nova_linha.append(novo)
    nova_lista.append(nova_linha)
    
nova_imagem = np.asarray(nova_lista)
nova_imagem.shape
# Out:
# (240, 320)

# %%
hist,bins = np.histogram(nova_imagem.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(nova_imagem.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# 3.

# %%
plt.imshow(nova_imagem, cmap="Greys_r", vmin=0, vmax=255)

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %%
box = cv2.imread("hall_box_battery1.jpg")

# %%
# plt.imshow(box,interpolation="none")

# %%
box_rgb = cv2.cvtColor(box, cv2.COLOR_BGR2RGB)
# plt.imshow(box_rgb,interpolation="none")

# %% [markdown]
# SEPARANDO OS CANAIS DA IMAGEM

# %%
box_r = box_rgb[:,:,0]
plt.imshow(box_r, cmap='Greys_r')

# %%
hist,bins = np.histogram(box_r.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(box_r.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
box_b = box_rgb[:,:,2]
plt.imshow(box_b, cmap='Greys_r')

# %%
hist,bins = np.histogram(box_b.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(box_b.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# 1. Não é possível identificar a caixa vermelha e a bateria azul. Após análise dos histogramas, percebe-se um certo padrão nos pixels na faixa de 75 - 150 devido a sua forma. Visto que a cor branca, percebida no rodapé da parede, é composta por pixels fortes de vermelho e azul (aparecendo nos dois histogramas), fica dificil identificar tanto a bateria quanto a caixa.

# %%
only_box_r = []

for linha in box_r:
    nova_linha = []
    for pixel in linha:
        if pixel > 150:
            nova_linha.append(pixel)
        else:
            nova_linha.append(0)
    only_box_r.append(nova_linha)
    
only_box_r = np.array(only_box_r)
plt.imshow(only_box_r, cmap='Greys_r')

# %% [markdown]
# 2.

# %%
only_box_r = box_rgb.copy()

for linha in range(box_rgb.shape[0]):
    for coluna in range(box_rgb.shape[1]):
        if int(box_rgb[linha, coluna, 0]) - int(box_rgb[linha, coluna, 1]) > 60 and int(box_rgb[linha, coluna, 0]) - int(box_rgb[linha, coluna, 2]) > 60:
            only_box_r[linha][coluna] = 255
        else:
            only_box_r[linha][coluna] = 0

plt.imshow(only_box_r, cmap='Greys_r')

# %%
only_box_r = box_rgb.copy()

for linha in range(box_rgb.shape[0]):
    for coluna in range(box_rgb.shape[1]):
        if int(box_rgb[linha, coluna, 0]) - int(box_rgb[linha, coluna, 1]) > 60 and int(box_rgb[linha, coluna, 0]) - int(box_rgb[linha, coluna, 2]) > 60:
            only_box_r[linha][coluna][0] = 255
            only_box_r[linha][coluna][1] = 0
            only_box_r[linha][coluna][2] = 0
        else:
            only_box_r[linha][coluna][0] = 0
            only_box_r[linha][coluna][1] = 0
            only_box_r[linha][coluna][2] = 0
            
plt.imshow(only_box_r, cmap='Greys_r')

# %% [markdown]
# # Atividade 3
#
#
# Crie uma cópia da imagem `hall_box_battery_atividade3.png`  em que cada pixel  recebe a subtração entre o pixel que vem depois e o que vem antes dele. Apresente a imagem resultado.

# %% [markdown]
# ![](hall_box_battery_atividade3.png)

# %%
box3 = cv2.imread("hall_box_battery_atividade3.png")

# %%
box3_rgb = cv2.cvtColor(box3, cv2.COLOR_BGR2GRAY)

# %%
ativ3_rgb = box3_rgb.copy()

for linha in range(box3_rgb.shape[0]):
    for coluna in range(1,box3_rgb.shape[1] - 1):
        subtracao = int(box3_rgb[linha][coluna+1]) - int(box3_rgb[linha][coluna-1])
        if subtracao >= 0 and subtracao <= 255:
            ativ3_rgb[linha][coluna] = subtracao
        else:
            if subtracao < 0:
                subtracao = abs(subtracao)
            ativ3_rgb[linha][coluna] = subtracao

plt.imshow(ativ3_rgb, cmap='Greys_r')
